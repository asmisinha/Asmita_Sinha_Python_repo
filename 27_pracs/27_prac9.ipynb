# %%
# Student class definition 
class Student: 
    def __init__(self, roll_no, name, course, percentage): 
        self.roll_no = roll_no 
        self.name = name 
        self.course = course 
        self.percentage = percentage 

    def display(self): 
        print("Roll No:", self.roll_no) 
        print("Name:", self.name) 
        print("Course:", self.course) 
        print("Percentage:", self.percentage) 
        print("-------------------------") 

# List to store student objects 
students = [] 

n = int(input("Enter number of students: ")) 

for i in range(n): 
    print("\nEnter details of student", i + 1) 
    r = int(input("Roll Number: ")) 
    name = input("Name: ") 
    c = input("Course: ") 
    p = float(input("Percentage: ")) 

    s = Student(r, nme, c, p) 
    students.append(s) 

# Display all students 
print("\n--- Student Details ---") 

for s in students: 
    s.display()
# Out:
# Enter number of students:  2
# Enter details of student 1
# Roll Number:  01
# Name:  Ram
# Course:  TE
# Percentage:  85
# Enter details of student 2
# Roll Number:  10
# Name:  Ali
# Course:  CO
# Percentage:  50
# --- Student Details ---
# Roll No: 1
# Name: Sam
# Course: TE
# Percentage: 85.0
# -------------------------
# Roll No: 10
# Name: Sam
# Course: CO
# Percentage: 50.0
# -------------------------

# %%
class Student:
    def __init__(self, name, roll_no, age, course):
        self.name = name
        self.roll_no = roll_no
        self.age = age
        self.course = course

    def display_details(self):
        print("Student Details")
        print("Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Age:", self.age)
        print("Course:", self.course)


student1 = Student("DUDE", 26, 17, "Computer Science")

student1.display_details()
# Out:
# Student Details
# Name: DUDE
# Roll No: 26
# Age: 17
# Course: Computer Science

# %%
class Student:
    def __init__(self, name, roll_no, age, course):
        self.name = name
        self.roll_no = roll_no
        self.age = age
        self.course = course

    def display(self):
        print("Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Age:", self.age)
        print("Course:", self.course)
        print("-" * 20)


students = []

n = int(input("Enter number of students: "))

for i in range(n):
    print(f"\nEnter details of student {i + 1}")
    name = input("Name: ")
    roll_no = int(input("Roll No: "))
    age = int(input("Age: "))
    course = input("Course: ")

    student = Student(name, roll_no, age, course)
    students.append(student)


print("\nStudent Details")
for student in students:
    student.display()
# Out:
# Enter number of students:  2
# Enter details of student 1
# Name:  Sage
# Roll No:  22
# Age:  26
# Course:  CO
# Enter details of student 2
# Name:  Reyna
# Roll No:  29
# Age:  29
# Course:  CO
# Student Details
# Name: Sage
# Roll No: 22
# Age: 26
# Course: CO
# --------------------
# Name: Reyna
# Roll No: 29
# Age: 29
# Course: CO
# --------------------

# %%
class Student:
    def show(self):
        print("Hello")

obj = Student()
obj.show()
# Out:
# Hello

# %%
class Student:
    def __init__(self):
        self.name = "Amit"
