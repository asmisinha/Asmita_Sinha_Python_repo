# %%
print("Asmita")
# Out:
# Asmita

# %%
r1=float(input("r1="))
r2=float(input("r2="))
rs=r1+r2
print(rs)
# Out:
# r1= 4
# r2= 5
# 9.0

# %%
print("Asmita")
# Out:
# Asmita

# %%
r1=float(input("r1"))
r2=float(input("r2"))
rp=1/(1/r1)+(1/r2)
print(rp)
# Out:
# r1 5
# r2 5
# 5.2

# %%
print("Asmita")
# Out:
# Asmita

# %%
i=20
r=30
v=i*r
print(v)
# Out:
# 600

# %%
print("Asmita")
# Out:
# Asmita

# %%
R1 = input("R1: ")
R2 = input("R2: ")
Rs = R1 + R2
print(Rs)
# Out:
# R1:  4
# R2:  7
# 47

# %%
R1 = float(input("R1: "))
R2 = float(input("R2: "))
Rs = R1 + R2
print(Rs)
# Out:
# R1:  8
# R2:  6
# 14.0

# %%
I = float(input("I: "))
R = float(input("R: "))
V = I * R
print(V)
# Out:
# I:  6
# R:  5
# 30.0

# %%
V = I * R
I = float(input("I: "))
R = float(input("R: "))
print(V)
# Out:
# I:  6
# R:  8
# 30.0
