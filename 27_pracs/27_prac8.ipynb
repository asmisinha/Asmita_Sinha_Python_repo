# %%
import math

num = int(input("Enter a number: "))

print("Power (num^2):", math.pow(num, 2))
print("Ceiling value:", math.ceil(5.4))
print("Square root:", math.sqrt(num))
print("Factorial:", math.factorial(num))
# Out:
# Enter a number:  31
# Power (num^2): 961.0
# Ceiling value: 6
# Square root: 5.5677643628300215
# Factorial: 8222838654177922817725562880000000

# %%
s1 = input("\nEnter a string: ") 
s2 = input("Enter another string: ") 
print("Uppercase:", s1.upper()) 
print("Lowercase:", s1.lower()) 
print("Replaced string:", s1.replace("Python", "Java")) 
print("Position of 'is':", s1.find("is")) 
print("Concatenated string:", s1 + " " + s2)
# Out:
# Enter a string:  PYTHON
# Enter another string:  PROGRAMMING
# Uppercase: PYTHON
# Lowercase: python
# Replaced string: PYTHON
# Position of 'is': -1
# Concatenated string: PYTHON PROGRAMMING

# %%
x = int(input("\nEnter first bit for Half Adder: ")) 
y = int(input("Enter second bit for Half Adder: ")) 
s, c = half_adder(x, y) 
print("Half Adder Sum:", s, "Carry:", c)
# Out:
# Enter first bit for Half Adder:  1
# Enter second bit for Half Adder:  0
# Half Adder Sum: 1 Carry: 0

# %%
x = int(input("\nEnter first bit for Full Adder: ")) 
y = int(input("Enter second bit for Full Adder: ")) 
cin = int(input("Enter carry-in: ")) 
s, c = full_adder(x, y, cin) 
print("Full Adder Sum:", s, "Carry:", c)
# Out:
# Enter first bit for Full Adder:  1
# Enter second bit for Full Adder:  1
# Enter carry-in:  1
# Full Adder Sum: 1 Carry: 1

# %%
text = "Python is a powerful language" 
index = text.find("language") 
print("\nIndex of word 'language':", index)
# Out:
# Index of word 'language': 21

# %%
import math
print(sqrt(25))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 import math
# ----> 2 print(sqrt(25))
#
# NameError: name 'sqrt' is not defined

# %%
import math 

print(math.sqrt(25))
# Out:
# 5.0

# %%
def add(a, b)
    return a + b
# Out:
#   Cell In[22], line 1
#     def add(a, b)
#                  ^
# SyntaxError: expected ':'

# %%
def add(a, b):
    return a + b
